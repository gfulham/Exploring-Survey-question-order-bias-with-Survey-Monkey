# %% [markdown]
# # Survey Monkey Deliver
#
# - Data has been cleaned in a previous notebook and is prepped for Survey Monkey
# - This notebook aims to  present findings to Survey Monkey from the cleaned data in regards to question-answer bias.
#
# # Imports

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import qgrid

# %% [markdown]
# # Get Data

# %%
df = pd.read_excel("C:\\Users\\gfulham\\Code\\Projects\\survey-monkey\\data\\survey_monkey_final.xlsx")
widget = qgrid.show_grid(df)
widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %% [markdown]
# # Transform Data

# %%
# count variable shows the responses to each question 
count = df.groupby(["Answer",'Question and Subquestion']).count().unstack()
print(count)

# total shows the total count each answer 1-8 recieved from all the questions
total = df.groupby(["Answer"]).count()["Respondents"]
print(total)
# Out:
#                                  Respondent ID                           \
# Question and Subquestion Question 1 - Response Question 10 - Response 1
# Answer
# Answer 1                                    14                       11
# Answer 2                                    10                        7
# Answer 3                                    13                       11
# Answer 4                                    17                       19
# Answer 5                                    22                       18
# Answer 6                                    16                       17
# Answer 7                                    11                       14
# Answer 8                                    16                       16
#
#                                                                             \
# Question and Subquestion Question 10 - Response 2 Question 10 - Response 3
# Answer
# Answer 1                                       21                       11
# ...

# %% [markdown]
# # Visualize Data

# %%
fig = plt.figure(figsize = (16,8))
st = fig.suptitle("Survey Answer Order Bias", fontsize = 'xx-large')

ax1 = fig.add_subplot(121)
ax1.plot(count, alpha = .1)
plt.ylabel("Num of Responses Per Question", fontsize="large")

ax2 = fig.add_subplot(122)
plt.ylabel("Total Responses", fontsize="large")
ax2.plot(total)
plt.savefig("Survey Answer Order Bias")

# %% [markdown]
# # Conclusion
#
# In this single survey there seems to be a small amount of bias to answering the questions with answers 4-7. If the Survey is designed on a Likert scale, the normal distribution might be off, looking at the low amount of total responses for answer 3. This distribution of responses may be acceptable due to the number of respondents(198). Depends on the industry standard for question and answer bias.
