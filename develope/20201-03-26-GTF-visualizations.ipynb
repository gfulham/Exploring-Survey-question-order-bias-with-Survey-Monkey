# %% [markdown]
# # Survey Monkey Visualizations
#
# Since the data is anonomyous, we can see if there is any bias to the answers.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import qgrid

# %%
pwd = os.getcwd()
pwd
# Out:
# 'C:\\Users\\gfulham\\Code\\Projects\\survey-monkey'

# %%
df = pd.read_excel(pwd + "\\survey_monkey_final.xlsx")
df
# Out:
#        Respondent ID        Division Primary Division Secondary  \
# 0         5379192392          Infrastructure                NaN
# 1         2658722536                 Finance                NaN
# 2         4044163394          Infrastructure                NaN
# 3         5535865599          Infrastructure                NaN
# 4         3356802928         Port Operations                NaN
# ...              ...                     ...                ...
# 17023     7940065082          Infrastructure                NaN
# 17024     5157705612                 Finance                NaN
# 17025     9920755555         Port Operations                NaN
# 17026     6638341389          Infrastructure                NaN
# 17027     8114622230  Information Technology                NaN
#
#               Position                             Generation      Gender  \
# 0                Staff  Generation X (born between 1965-1980)        Male
# 1                Staff                                    NaN         NaN
# 2      Department Lead  Generation X (born between 1965-1980)        Male
# 3              Manager    Millennial (born between 1981-2000)  Non-Binary
# 4              Manager  Generation X (born between 1965-1980)      Female
# ...                ...                                    ...         ...
# 17023  Department Lead   Baby Boomer (born between 1946-1964)        Male
# 17024            Staff    Millennial (born between 1981-2000)      Female
# 17025            Staff    Millennial (born between 1981-2000)      Female
# 17026          Manager    Millennial (born between 1981-2000)      Female
# 17027            Staff                   Prefer not to answer        Male
#
#            Tenure     Employment Type  Question and Subquestion    Answer  \
# 0       0-2 years  Full time Employee     Question 1 - Response       NaN
# 1       10+ years  Full time Employee     Question 1 - Response  Answer 4
# 2       3-5 years  Full time Employee     Question 1 - Response  Answer 5
# 3      5-10 years  Full time Employee     Question 1 - Response  Answer 1
# 4       10+ years  Full time Employee     Question 1 - Response       NaN
# ...           ...                 ...                       ...       ...
# 17023   10+ years  Full time Employee  Question 30 - Response 3  Answer 8
# 17024  5-10 years  Full time Employee  Question 30 - Response 3  Answer 6
# 17025   3-5 years  Full time Employee  Question 30 - Response 3       NaN
# 17026   3-5 years  Full time Employee  Question 30 - Response 3       NaN
# 17027  5-10 years  Full time Employee  Question 30 - Response 3       NaN
#
#           Question  Respondents  Same Answer
# 0       Question 1          119          NaN
# 1       Question 1          119         17.0
# 2       Question 1          119         22.0
# 3       Question 1          119         14.0
# 4       Question 1          119          NaN
# ...            ...          ...          ...
# 17023  Question 30          182         14.0
# 17024  Question 30          182         20.0
# 17025  Question 30          182          NaN
# 17026  Question 30          182          NaN
# 17027  Question 30          182          NaN
#
# [17028 rows x 13 columns]

# %%
widget = qgrid.show_grid(df)
widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
df['Respondent ID'].nunique()
# Out:
# 198

# %%
count = df.groupby(["Answer",'Question and Subquestion']).count().unstack()
print(count)
# Out:
#                                  Respondent ID                           \
# Question and Subquestion Question 1 - Response Question 10 - Response 1
# Answer
# Answer 1                                    14                       11
# Answer 2                                    10                        7
# Answer 3                                    13                       11
# Answer 4                                    17                       19
# Answer 5                                    22                       18
# Answer 6                                    16                       17
# Answer 7                                    11                       14
# Answer 8                                    16                       16
#
#                                                                             \
# Question and Subquestion Question 10 - Response 2 Question 10 - Response 3
# Answer
# Answer 1                                       21                       11
# Answer 2                                       18                       21
# Answer 3                                       13                        8
# Answer 4                                       17                       21
# Answer 5                                       13                       18
# Answer 6                                       16                       14
# Answer 7                                        9                       13
# Answer 8                                       10                       17
#
#                                                                             \
# Question and Subquestion Question 10 - Response 4 Question 10 - Response 5
# Answer
# Answer 1                                       14                       25
# Answer 2                                        9                       19
# Answer 3                                       14                       17
# Answer 4                                       10                       15
# Answer 5                                       15                       12
# Answer 6                                       22                       14
# Answer 7                                       13                       10
# Answer 8                                       10                       13
#
#                                                                            \
# Question and Subquestion Question 11 - Reponse 1 Question 11 - Response 2
# Answer
# Answer 1                                      15                       18
# Answer 2                                      13                       11
# Answer 3                                      11                       17
# Answer 4                                      24                       16
# Answer 5                                      13                       17
# Answer 6                                      13                       10
# Answer 7                                      15                       15
# Answer 8                                      18                       13
#
#                                                                         ...  \
# Question and Subquestion Question 12 - Response Question 13 - Response  ...
# Answer                                                                  ...
# Answer 1                                     12                     14  ...
# Answer 2                                     15                     11  ...
# Answer 3                                     18                     10  ...
# Answer 4                                     11                     18  ...
# Answer 5                                     13                     21  ...
# Answer 6                                     15                     13  ...
# Answer 7                                     18                     11  ...
# Answer 8                                     12                     10  ...
#
#                                      Same Answer                           \
# Question and Subquestion Question 7 - Response 1 Question 7 - Unscheduled
# Answer
# Answer 1                                      21                       11
# Answer 2                                      12                       13
# Answer 3                                      11                       19
# Answer 4                                      18                       15
# Answer 5                                      17                       12
# Answer 6                                      14                       18
# Answer 7                                      14                       17
# Answer 8                                      11                       14
#
#                                                                           \
# Question and Subquestion Question 8 - Response 1 Question 8 - Response 2
# Answer
# Answer 1                                       5                      22
# Answer 2                                      11                       7
# Answer 3                                      13                      24
# Answer 4                                      17                      13
# Answer 5                                      19                      11
# Answer 6                                      11                       9
# Answer 7                                      17                      13
# Answer 8                                      24                      16
#
#                                                                           \
# Question and Subquestion Question 8 - Response 3 Question 8 - Response 4
# Answer
# Answer 1                                      15                      14
# Answer 2                                       9                      13
# Answer 3                                      15                      16
# Answer 4                                      13                      11
# Answer 5                                      14                      17
# Answer 6                                      11                       5
# Answer 7                                      15                      14
# Answer 8                                      18                      14
#
#                                                                           \
# Question and Subquestion Question 9 - Response 1 Question 9 - Response 2
# Answer
# Answer 1                                      15                      14
# Answer 2                                      15                      18
# Answer 3                                      20                      15
# Answer 4                                      12                      10
# Answer 5                                      14                      13
# Answer 6                                      13                      16
# Answer 7                                      17                      19
# Answer 8                                      15                       8
#
#
# Question and Subquestion Question 9 - Response 3 Question 9 - Response 4
# Answer
# Answer 1                                      15                      17
# Answer 2                                      16                      10
# Answer 3                                       6                      10
# Answer 4                                       9                      16
# Answer 5                                      20                      13
# Answer 6                                      16                      14
# Answer 7                                      14                      12
# Answer 8                                      12                      19
#
# [8 rows x 946 columns]

# %%
total = df.groupby(["Answer"]).count()["Respondents"]
total = total 
total
# Out:
# Answer
# Answer 1    1183
# Answer 2    1205
# Answer 3    1173
# Answer 4    1213
# Answer 5    1276
# Answer 6    1228
# Answer 7    1213
# Answer 8    1173
# Name: Respondents, dtype: int64

# %%
plt.figure(figsize=(16,6))

plt.subplot(1,2,1)
plt.plot(count, alpha = .1)
plt.title("Potential Bias to Survey Responses")
plt.ylabel("Number of Answers Per Question")
plt.xlabel("Answer", fontsize='large')

plt.subplot(1,2,2)
plt.plot(total)

# %%
fig = plt.figure(figsize = (16,8))
st = fig.suptitle("Potential Bias to Survey Responses", fontsize = 'xx-large')

ax1 = fig.add_subplot(121)
ax1.plot(count, alpha = .1)
plt.ylabel("Num of Responses Per Question", fontsize="large")

ax2 = fig.add_subplot(122)
plt.ylabel("Total Responses", fontsize="large")
ax2.plot(total)

# %% [markdown]
# ## Conclusion
#
# In this single survey there seems to be a small amount of Bias to answering the questions with answers 4-7. If the Survey is designed on a Likert scale, the normal distribution might be off, looking at the low amount of total responses for answer 3. This distribution of responses seems acceptable due to the number of respondents in the survey totaling 198.
